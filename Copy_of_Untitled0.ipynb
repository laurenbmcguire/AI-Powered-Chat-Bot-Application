# %% [markdown]
# <a href="https://colab.research.google.com/github/laurenbmcguire/AI-Powered-Chat-Bot-Application/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install sweetviz
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import sweetviz as sv
import pandas as pd

# %%
df=pd.read_csv('/bid.csv')

df
# Out:
#                                                btn href  \
# 0     https://bid.liquidbidding.com/lots/4722384#YXV...
# 1     https://bid.liquidbidding.com/lots/4709575#YXV...
# 2     https://bid.liquidbidding.com/lots/4720736#YXV...
# 3     https://bid.liquidbidding.com/lots/4720745#YXV...
# 4     https://bid.liquidbidding.com/lots/4720756#YXV...
# ...                                                 ...
# 1053  https://bid.liquidbidding.com/lots/4730254#YXV...
# 1054  https://bid.liquidbidding.com/lots/4730260#YXV...
# 1055  https://bid.liquidbidding.com/lots/4730266#YXV...
# 1056  https://bid.liquidbidding.com/lots/4730270#YXV...
# 1057  https://bid.liquidbidding.com/lots/4730274#YXV...
#
#                                      img-responsive src  item-lot-number 2  \
# 0     https://oasattachments.s3.amazonaws.com/49/202...            9009142
# 1     https://oasattachments.s3.amazonaws.com/49/202...            9010866
# ...

# %%
my_report = sv.analyze(pd.read_csv('/bid.csv')
)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # New Section
